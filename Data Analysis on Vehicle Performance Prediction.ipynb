# %%
import pandas as pd

# %%
df= pd.read_csv('Linear regression.csv')

# %%
df
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0         1          8         307.0        130    3504          12.0  1970
# 1         1          8         350.0        165    3693          11.5  1970
# 2         1          8         318.0        150    3436          11.0  1970
# 3         1          8         304.0        150    3433          12.0  1970
# 4         1          8         302.0        140    3449          10.5  1970
# ..      ...        ...           ...        ...     ...           ...   ...
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
#                           name  Kilometer_per_liter
# ...

# %%
df[df['origin']==1]['year'].nunique()
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
df['origin'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df['displacement'].unique()
# Out:
# array([307. , 350. , 318. , 304. , 302. , 429. , 454. , 440. , 455. ,
#        390. , 383. , 340. , 400. , 113. , 198. , 199. , 200. ,  97. ,
#        110. , 107. , 104. , 121. , 360. , 140. ,  98. , 232. , 225. ,
#        250. , 351. , 258. , 122. , 116. ,  79. ,  88. ,  71. ,  72. ,
#         91. ,  97.5,  70. , 120. ,  96. , 108. , 155. ,  68. , 114. ,
#        156. ,  76. ,  83. ,  90. , 231. , 262. , 134. , 119. , 171. ,
#        115. , 101. , 305. ,  85. , 130. , 168. , 111. , 260. , 151. ,
#        146. ,  80. ,  78. , 105. , 131. , 163. ,  89. , 267. ,  86. ,
#        183. , 141. , 173. , 135. ,  81. , 100. , 145. , 112. , 181. ,
#        144. ])

# %%
df[df['horsepower']=='?'].index
df.drop(index= df[df['horsepower']=='?'].index)
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0         1          8         307.0        130    3504          12.0  1970
# 1         1          8         350.0        165    3693          11.5  1970
# 2         1          8         318.0        150    3436          11.0  1970
# 3         1          8         304.0        150    3433          12.0  1970
# 4         1          8         302.0        140    3449          10.5  1970
# ..      ...        ...           ...        ...     ...           ...   ...
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
#                           name  Kilometer_per_liter
# ...

# %%
df['weight'].unique()
# Out:
# array([3504, 3693, 3436, 3433, 3449, 4341, 4354, 4312, 4425, 3850, 3563,
#        3609, 3761, 3086, 2372, 2833, 2774, 2587, 2130, 1835, 2672, 2430,
#        2375, 2234, 2648, 4615, 4376, 4382, 4732, 2264, 2228, 2046, 2634,
#        3439, 3329, 3302, 3288, 4209, 4464, 4154, 4096, 4955, 4746, 5140,
#        2962, 2408, 3282, 3139, 2220, 2123, 2074, 2065, 1773, 1613, 1834,
#        1955, 2278, 2126, 2254, 2226, 4274, 4385, 4135, 4129, 3672, 4633,
#        4502, 4456, 4422, 2330, 3892, 4098, 4294, 4077, 2933, 2511, 2979,
#        2189, 2395, 2288, 2506, 2164, 2100, 4100, 3988, 4042, 3777, 4952,
#        4363, 4237, 4735, 4951, 3821, 3121, 3278, 2945, 3021, 2904, 1950,
#        4997, 4906, 4654, 4499, 2789, 2279, 2401, 2379, 2124, 2310, 2472,
#        2265, 4082, 4278, 1867, 2158, 2582, 2868, 3399, 2660, 2807, 3664,
#        3102, 2875, 2901, 3336, 2451, 1836, 2542, 3781, 3632, 3613, 4141,
#        4699, 4457, 4638, 4257, 2219, 1963, 2300, 1649, 2003, 2125, 2108,
# ...

# %%
df['acceleration'].unique()
# Out:
# array([12. , 11.5, 11. , 10.5, 10. ,  9. ,  8.5,  8. ,  9.5, 15. , 15.5,
#        16. , 14.5, 20.5, 17.5, 12.5, 14. , 13.5, 18.5, 19. , 13. , 19.5,
#        18. , 17. , 23.5, 16.5, 21. , 16.9, 14.9, 17.7, 15.3, 13.9, 12.8,
#        15.4, 17.6, 22.2, 22.1, 14.2, 17.4, 16.2, 17.8, 12.2, 16.4, 13.6,
#        15.7, 13.2, 21.9, 16.7, 12.1, 14.8, 18.6, 16.8, 13.7, 11.1, 11.4,
#        18.2, 15.8, 15.9, 14.1, 21.5, 14.4, 19.4, 19.2, 17.2, 18.7, 15.1,
#        13.4, 11.2, 14.7, 16.6, 17.3, 15.2, 14.3, 20.1, 24.8, 11.3, 12.9,
#        18.8, 18.1, 17.9, 21.7, 23.7, 19.9, 21.8, 13.8, 12.6, 16.1, 20.7,
#        18.3, 20.4, 19.6, 17.1, 15.6, 24.6, 11.6])

# %%
df['year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982], dtype=int64)

# %%
df['name'].nunique()
# Out:
# 305

# %%
df[df['Kilometer_per_liter']==df['Kilometer_per_liter'].max()]
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 322       3          4          86.0         65    2110          17.9  1980
#
#           name  Kilometer_per_liter
# 322  mazda glc            19.811697

# %%
df['year'].dtype
# Out:
# dtype('int64')

# %%
import matplotlib.pyplot as plt
df.set_index('name').sort_values(by= 'Kilometer_per_liter', ascending= False)[['Kilometer_per_liter']].head()
plt.figure(figsize= (15,3));
plt.plot(df.set_index('name').sort_values(by= 'Kilometer_per_liter', ascending= False)[['Kilometer_per_liter']].head())
plt.xticks(rotation=45)
plt.title('5 Vehicles with best Mileage')
# Out:
# Text(0.5, 1.0, '5 Vehicles with best Mileage')

# %%
df.reset_index().set_index(['name','cylinders'])
# Out:
#                                      index  origin  displacement horsepower  \
# name                      cylinders
# chevrolet chevelle malibu 8              0       1         307.0        130
# buick skylark 320         8              1       1         350.0        165
# plymouth satellite        8              2       1         318.0        150
# amc rebel sst             8              3       1         304.0        150
# ford torino               8              4       1         302.0        140
# ...                                    ...     ...           ...        ...
# ford mustang gl           4            393       1         140.0         86
# vw pickup                 4            394       2          97.0         52
# dodge rampage             4            395       1         135.0         84
# ford ranger               4            396       1         120.0         79
# chevy s-10                4            397       1         119.0         82
#
# ...

# %%
df[df['cylinders']==8].sort_values('Kilometer_per_liter', ascending= False)
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 364       1          8         350.0        105    3725          19.0  1981
# 300       1          8         260.0         90    3420          22.2  1979
# 298       1          8         350.0        125    3900          17.4  1979
# 251       1          8         302.0        139    3570          12.8  1978
# 165       1          8         262.0        110    3221          13.5  1975
# ..      ...        ...           ...        ...     ...           ...   ...
# 124       1          8         350.0        180    3664          11.0  1973
# 27        1          8         318.0        210    4382          13.5  1970
# 25        1          8         360.0        215    4615          14.0  1970
# 26        1          8         307.0        200    4376          15.0  1970
# 28        1          8         304.0        193    4732          18.5  1970
#
# ...

# %%
df['year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982], dtype=int64)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
plt.figure(figsize= (10,5))
plt.scatter( df['displacement'],df['Kilometer_per_liter'])
plt.xlabel('displacement')
plt.ylabel('KMPL')
plt.title('KMPH vs Disp')
plt.show()

# %%
plt.figure(figsize= (10,5))
plt.scatter( df['weight'],df['Kilometer_per_liter'])
plt.xlabel('weight')
plt.ylabel('KMPL')
plt.title('KMPH vs weight')
plt.show()

# %%
plt.figure(figsize= (10,3))
plt.scatter( df['horsepower'],df['Kilometer_per_liter'])
plt.xlabel('horsepower')
plt.ylabel('KMPL')
plt.title('KMPH vs horsepower')
plt.show()

# %%
plt.figure(figsize= (10,3))
plt.scatter( df['acceleration'],df['Kilometer_per_liter'])
plt.xlabel('acceleration')
plt.ylabel('KMPL')
plt.title('KMPL vs acceleration')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df[df['horsepower']=='?'].index
df.drop(index= df[df['horsepower']=='?'].index, inplace= True)

# %%
df['horsepower']=df['horsepower'].astype('int')

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs= RobustScaler()

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd= SGDRegressor()

# %%
df['origin']= df['origin'].astype('category')
df['cylinders']= df['cylinders'].astype('category')
df['year']= df['year'].astype('category')

# %%
X= df.drop(['Kilometer_per_liter','name'], axis=1)

# %%
y= df['Kilometer_per_liter']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.3)

# %%
Scaled_train= rs.fit_transform(X_train)
Scaled_test= rs.transform(X_test)

# %%
sgd.fit(Scaled_train,y_train)
# Out:
# SGDRegressor()

# %%
y_pred= sgd.predict(Scaled-_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.11477705517775302

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7677400119393586

# %%
df['name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'plymouth satellite custom', 'ford torino 500', 'amc matador',
#        'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
#        'pontiac firebird', 'ford mustang', 'mercury capri 2000',
# ...

# %%
df[df.duplicated('name')]['name']
# Out:
# 29                  datsun pl510
# 33                   amc gremlin
# 35     chevrolet chevelle malibu
# 38              chevrolet impala
# 40              ford galaxie 500
#                  ...
# 363                buick century
# 372              pontiac phoenix
# 381                 honda accord
# 382               toyota corolla
# 383                  honda civic
# Name: name, Length: 91, dtype: object

# %%
df[df.duplicated('name')]['name'].unique()
# Out:
# array(['datsun pl510', 'amc gremlin', 'chevrolet chevelle malibu',
#        'chevrolet impala', 'ford galaxie 500', 'plymouth fury iii',
#        'pontiac catalina', 'amc matador', 'amc hornet', 'ford maverick',
#        'plymouth duster', 'chevrolet vega', 'ford pinto',
#        'toyota corolla 1200', 'ford gran torino', 'ford gran torino (sw)',
#        'amc matador (sw)', 'opel manta', 'toyota corona', 'fiat 128',
#        'chevrolet nova', 'ford ltd', 'volkswagen dasher', 'datsun 710',
#        'audi 100ls', 'peugeot 504', 'saab 99le', 'opel 1900',
#        'dodge colt', 'chevrolet chevelle malibu classic',
#        'plymouth valiant', 'honda civic', 'volkswagen rabbit',
#        'toyota corolla', 'toyota mark ii', 'chevrolet caprice classic',
#        'chevrolet chevette', 'honda civic cvcc', 'chevrolet malibu',
#        'chevrolet monte carlo landau', 'buick estate wagon (sw)',
#        'ford country squire (sw)', 'oldsmobile cutlass salon brougham',
# ...

# %%
df
# Out:
#     origin cylinders  displacement  horsepower  weight  acceleration  year  \
# 0        1         8         307.0         130    3504          12.0  1970
# 1        1         8         350.0         165    3693          11.5  1970
# 2        1         8         318.0         150    3436          11.0  1970
# 3        1         8         304.0         150    3433          12.0  1970
# 4        1         8         302.0         140    3449          10.5  1970
# ..     ...       ...           ...         ...     ...           ...   ...
# 393      1         4         140.0          86    2790          15.6  1982
# 394      2         4          97.0          52    2130          24.6  1982
# 395      1         4         135.0          84    2295          11.6  1982
# 396      1         4         120.0          79    2625          18.6  1982
# 397      1         4         119.0          82    2720          19.4  1982
#
#                           name  Kilometer_per_liter
# ...

# %%
df.reset_index(inplace= True)

# %%
def first_ele(s):
    for i in range(len(s)):
        if (s[i]==' ')or (i==len(s)-1):
            return(s[:i])
            break

# %%
first_ele('dodge rampage')
# Out:
# 'dodge'

# %%
df['brand']= df['name'].apply(lambda x:str(first_ele(x)))

# %%
df['name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 387              ford mustang gl
# 388                    vw pickup
# 389                dodge rampage
# 390                  ford ranger
# 391                   chevy s-10
# Name: name, Length: 392, dtype: object

# %%
df['brand'].nunique()
# Out:
# 38

# %%
df['cylinders'].unique()
# Out:
# [8, 4, 6, 3, 5]
# Categories (5, int64): [8, 4, 6, 3, 5]

# %%
for i in df['brand'].unique():
    plt.bar(df[(df['brand']== i)]['cylinders'], df[df['brand']==i]['Kilometer_per_liter'])
    plt.xlabel('No. of Cylinders')
    plt.ylabel('KMPL')
    plt.title(i+ 'Cars')
    plt.show()

# %%
df.groupby('brand', sort= False)['origin'].first().plot(kind='bar');

# %%
df.groupby('origin')['brand'].nunique().plot(kind='bar')
plt.show()

# %%
plt.title('Percentage of cars in every origin')
plt.pie(df.groupby('origin')['brand'].nunique(),labels = ['origin1','origin2','origin3'], autopct = '%1.1f%%')
plt.show()

# %%
df.groupby('origin')['brand'].nunique()
# Out:
# origin
# 1    15
# 2    14
# 3     9
# Name: brand, dtype: int64

# %% [markdown]
# # Chevrolet Cars have only one origin 1

# %%
df[df['brand']=='chevrolet']['origin'].unique()
# Out:
# [1]
# Categories (1, int64): [1]

# %%
df[df['brand']=='chevrolet']['cylinders'].unique()
# Out:
# [8, 4, 6]
# Categories (3, int64): [8, 4, 6]

# %%
df[(df['brand']=='chevrolet') & (df['cylinders']==8)]['Kilometer_per_liter'].max()
# Out:
# 8.502874149

# %%
df[(df['brand']=='chevrolet') & (df['cylinders']==6)]['Kilometer_per_liter'].max()
# Out:
# 12.24413877

# %%
df[(df['brand']=='chevrolet') & (df['cylinders']==4)]['Kilometer_per_liter'].max()
# Out:
# 14.45488605

# %%
plt.bar(df[(df['brand']=='chevrolet')]['cylinders'], df[df['brand']=='chevrolet']['Kilometer_per_liter'])
plt.xlabel('No. of Cylinders')
plt.ylabel('KMPL')
plt.title('Chevrolet Cars')
plt.show()

# %%
plt.bar(df[(df['brand']=='ford')]['cylinders'], df[df['brand']=='ford']['Kilometer_per_liter'])
plt.xlabel('No. of Cylinders')
plt.ylabel('KMPL')
plt.title('ford Cars')
plt.show()

# %%
df[(df['brand']=='mercedes')]['cylinders'].unique()
# Out:
# [5]
# Categories (1, int64): [5]

# %%
df[(df['brand']=='honda')]['cylinders'].unique()
# Out:
# [4]
# Categories (1, int64): [4]

# %%
df[(df['brand']=='toyota')]['cylinders'].unique()
# Out:
# [4, 6]
# Categories (2, int64): [4, 6]

# %%
plt.bar(df['cylinders'].unique(),df.groupby('cylinders')['Kilometer_per_liter'].mean())
plt.xlabel('No. of cylinders')
plt.ylabel('KMPL')
plt.title('Average Performance based on number of cylinders')
plt.show()

# %%
df
# Out:
#      index origin cylinders  displacement  horsepower  weight  acceleration  \
# 0        0      1         8         307.0         130    3504          12.0
# 1        1      1         8         350.0         165    3693          11.5
# 2        2      1         8         318.0         150    3436          11.0
# 3        3      1         8         304.0         150    3433          12.0
# 4        4      1         8         302.0         140    3449          10.5
# ..     ...    ...       ...           ...         ...     ...           ...
# 387    393      1         4         140.0          86    2790          15.6
# 388    394      2         4          97.0          52    2130          24.6
# 389    395      1         4         135.0          84    2295          11.6
# 390    396      1         4         120.0          79    2625          18.6
# 391    397      1         4         119.0          82    2720          19.4
#
# ...

# %%
plt.figure(figsize=(12,5))
plt.bar(df['brand'].unique(),df.groupby(['brand'])['Kilometer_per_liter'].mean())
plt.xticks(rotation= 90)
plt.xlabel('Brand')
plt.ylabel('KMPL')
plt.title('Average Brand Performance')
plt.show()

# %%
df
# Out:
#      index origin cylinders  displacement  horsepower  weight  acceleration  \
# 0        0      1         8         307.0         130    3504          12.0
# 1        1      1         8         350.0         165    3693          11.5
# 2        2      1         8         318.0         150    3436          11.0
# 3        3      1         8         304.0         150    3433          12.0
# 4        4      1         8         302.0         140    3449          10.5
# ..     ...    ...       ...           ...         ...     ...           ...
# 387    393      1         4         140.0          86    2790          15.6
# 388    394      2         4          97.0          52    2130          24.6
# 389    395      1         4         135.0          84    2295          11.6
# 390    396      1         4         120.0          79    2625          18.6
# 391    397      1         4         119.0          82    2720          19.4
#
# ...

# %%
df.sort_values('displacement', ascending= False)[['displacement','Kilometer_per_liter']].head(20)
# Out:
#      displacement  Kilometer_per_liter
# 8           455.0             5.952012
# 94          455.0             5.101724
# 13          455.0             5.952012
# 6           454.0             5.952012
# 7           440.0             5.952012
# 93          440.0             5.526868
# 89          429.0             5.101724
# 5           429.0             6.377156
# 66          429.0             4.676581
# 62          400.0             5.952012
# 227         400.0             6.802299
# 103         400.0             5.101724
# 102         400.0             4.676581
# 115         400.0             6.802299
# 38          400.0             5.952012
# 42          400.0             5.526868
# 229         400.0             6.589727
# 69          400.0             5.526868
# 43          400.0             5.526868
# 12          400.0             6.377156

# %%
plt.figure(figsize=(12,4))
plt.bar(df['brand'].unique(),df.groupby('brand', sort= False)['displacement'].mean())
plt.xticks(rotation= -90)
plt.show()

# %%
df.groupby(['brand','name']).first()
# Out:
#                                index origin cylinders  displacement  \
# brand name
# amc   amc ambassador brougham     96      1         8         360.0
#       amc ambassador dpl           9      1         8         390.0
#       amc ambassador sst          66      1         8         304.0
#       amc concord                257      1         6         232.0
#       amc concord d/l            261      1         6         258.0
# ...                              ...    ...       ...           ...
# vw    vw dasher (diesel)         326      2         4          90.0
#       vw pickup                  394      2         4          97.0
#       vw rabbit                  197      2         4          90.0
#       vw rabbit c (diesel)       325      2         4          90.0
#       vw rabbit custom           293      2         4          89.0
#
#                                horsepower  weight  acceleration  year  \
# brand name
# ...

# %%
df.groupby('origin')['cylinders'].unique()
# Out:
# origin
# 1    [8, 6, 4]
# Categories (3, int64): [8, 6, 4]
# 2    [4, 6, 5]
# Categories (3, int64): [4, 6, 5]
# 3    [4, 3, 6]
# Categories (3, int64): [4, 3, 6]
# Name: cylinders, dtype: object

# %%
df.groupby('brand')['name'].value_counts()
# Out:
# brand  name
# amc    amc matador             5
#        amc gremlin             4
#        amc hornet              4
#        amc concord             2
#        amc matador (sw)        2
#                               ..
# vw     vw rabbit               2
#        vw dasher (diesel)      1
#        vw pickup               1
#        vw rabbit c (diesel)    1
#        vw rabbit custom        1
# Name: name, Length: 301, dtype: int64

# %%
plt.bar(df['year'].unique(), df.groupby('year')['Kilometer_per_liter'].mean())
plt.show()

# %%
plt.bar(df['horsepower'].unique(),df.groupby('horsepower')['Kilometer_per_liter'].mean())
# Out:
# <BarContainer object of 93 artists>

# %%
plt.scatter(df['displacement'], df['acceleration'])
plt.show()

# %%
df.groupby(['year','brand'])['name'].value_counts().head(50)
# Out:
# year  brand       name
# 1970  amc         amc ambassador dpl              1
#                   amc gremlin                     1
#                   amc hornet                      1
#                   amc rebel sst                   1
#       audi        audi 100 ls                     1
#       bmw         bmw 2002                        1
#       buick       buick estate wagon (sw)         1
#                   buick skylark 320               1
#       chevrolet   chevrolet chevelle malibu       1
#                   chevrolet impala                1
#                   chevrolet monte carlo           1
#       chevy       chevy c20                       1
#       datsun      datsun pl510                    1
#       dodge       dodge challenger se             1
#                   dodge d200                      1
#       ford        ford f250                       1
#                   ford galaxie 500                1
#                   ford maverick                   1
# ...
